# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Import packages

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    root_mean_squared_error,
    mean_squared_error,
    mean_absolute_error,
    r2_score,
    make_scorer,
)
import pandas as pd
import numpy as np
import pickle
import os

# %%
CLEAN_DATA_FOLDER = "clean_data"
MODELS_FOLDER = "models"

# %% [markdown]
# ## Load the dataframe

# %%
train_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "train_wo_weather.csv"))
test_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "test_wo_weather.csv")).sort_values(
    ["Day", "Line", "Service", "Direction Number", "Sequence"]
)

# %% [markdown]
# ## Split into X and y

# %%
train_X = train_df[[x for x in train_df.columns if x not in ["On", "Off"]]]
train_y = train_df["On"]
test_X = test_df[[x for x in test_df.columns if x not in ["On", "Off"]]]
test_y = test_df["On"]

# %% [markdown]
# ## Train the Decision Tree Regressor Model

# %%
dt = DecisionTreeRegressor(random_state=42, criterion="poisson")
dt = dt.fit(X=train_X, y=train_y)

# %%
train_y_pred = np.floor(dt.predict(train_X)).astype(int)
test_y_pred = np.floor(dt.predict(test_X)).astype(int)

# %% [markdown]
# ## Plot the Tree

# %%
# _, ax = plt.subplots(1, 1, figsize=(32, 14))
# _ = plot_tree(
#     dt,
#     max_depth=4,
#     feature_names=train_X.columns,
#     filled=True,
#     proportion=True,
#     rounded=True,
#     precision=2,
#     fontsize=9,
#     ax=ax,
# )

# %% [markdown]
# ## Feature Importance

# %%
# feat_imp = pd.DataFrame(
#     {
#         "Feature": [x for x in dt.feature_names_in_],
#         "Importance": [x for x in dt.feature_importances_],
#     }
# )
# _, ax = plt.subplots(1, 1, figsize=(16, 9))
# _ = sns.barplot(feat_imp, x="Feature", y="Importance")
# _ = plt.title("Feature Importance for Decision Tree Regressor")

# %% [markdown]
# ## Visualize the Predictions

# %%
# line_fit = pd.DataFrame({"True": test_y, "Predicted": test_y_pred}, index=test_df["Day"])
# _, ax = plt.subplots(1, 1, figsize=(16,9))
# _ = sns.lineplot(line_fit, legend=True, ax=ax)

# %% [markdown]
# ## Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 16.310750216199562
# train mae: 3.386988032495105
# train r2 score: 0.8919976104787393

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 37.58158037687529
# test mae: 9.581289629916652
# test r2 score: 0.39458018689686514

# %% [markdown]
# ## Export Model

# %%
pickle.dump(dt, open(os.path.join(MODELS_FOLDER, "base_decision_tree_wo_weather.pkl"), "wb"))

# %% [markdown]
# ## Hyperparameter Tuning with GridSearchCV

# %% [markdown]
# ### Declare base model and parameters

# %%
base_dt = DecisionTreeRegressor(random_state=42)
param_grid = [
    {
        "criterion": ["squared_error", "friedman_mse", "poisson"],
        "max_depth": [20, 40, None],
        "min_samples_split": [2],
        "min_samples_leaf": [1],
    },
    {
        "criterion": ["squared_error", "friedman_mse", "poisson"],
        "max_depth": [20, 40, None],
        "min_samples_split": [14],
        "min_samples_leaf": [7],
    },
]

# %% [markdown]
# ### Declare the scorer and grid search

# %%
scorer = make_scorer(mean_squared_error, greater_is_better=False)
grid_search = GridSearchCV(base_dt, param_grid, scoring=scorer, n_jobs=-1, verbose=2, cv=5)

# %% [markdown]
# ### Train the models

# %%
grid_search.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.2s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.3s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.3s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.4s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.6s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  25.0s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  25.1s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  25.2s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  25.8s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  25.8s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.3s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  25.8s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  25.7s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  26.0s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  21.2s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  21.2s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  26.1s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  20.9s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  21.4s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  27.1s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  26.3s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  25.9s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  26.1s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  26.2s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  26.6s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  26.5s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  26.8s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  26.5s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  27.7s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  27.4s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  23.8s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  23.8s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  24.7s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  24.3s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  24.4s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  30.5s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  30.9s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  31.2s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  30.9s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  31.0s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  20.4s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  20.7s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  29.2s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  28.8s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  20.8s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  29.0s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  28.8s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  20.2s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  29.1s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  20.4s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  21.3s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  21.3s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  21.4s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  21.5s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  21.6s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  21.2s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  21.3s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  21.2s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  21.5s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  21.3s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  18.0s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  18.0s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  17.9s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  18.7s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  18.6s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  22.3s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  22.5s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  22.6s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  22.8s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  22.9s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.1s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  24.8s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.2s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.4s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.2s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  22.0s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  22.0s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  22.6s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  22.2s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  22.7s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  26.1s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  26.1s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  26.8s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  26.4s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  26.3s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.9s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.6s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.4s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.5s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  25.3s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid=[{'criterion': ['squared_error', 'friedman_mse',
#                                         'poisson'],
#                           'max_depth': [20, 40, None], 'min_samples_leaf': [1],
#                           'min_samples_split': [2]},
#                          {'criterion': ['squared_error', 'friedman_mse',
#                                         'poisson'],
#                           'max_depth': [20, 40, None], 'min_samples_leaf': [7],
#                           'min_samples_split': [14]}],
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       20.031031      0.156634         0.341155        0.010027
# 1       23.697423      0.299798         1.692238        0.055357
# 2       23.790865      0.380660         2.354581        0.119648
# 3       20.525642      0.346721         0.481808        0.085528
# 4       24.469335      0.350441         1.863414        0.078923
# 5       24.778765      0.407131         2.092934        0.195631
# 6       23.701582      0.382179         0.508263        0.036682
# 7       28.882256      0.237617         2.008212        0.075360
# 8       27.319026      0.166226         1.698273        0.049660
# 9       20.206816      0.239119         0.304821        0.017901
# 10      20.411257      0.158250         0.986657        0.066761
# 11      20.268579      0.124698         1.019247        0.036712
# 12      17.912888      0.326417         0.336792        0.012366
# 13      21.384264      0.322459         1.221940        0.094951
# 14      23.944559      0.177358         1.191233        0.029899
# 15      21.977782      0.288044         0.314084        0.011566
# 16      25.430746      0.290602         0.910259        0.057474
# 17      24.877353      0.119981         0.667668        0.123959
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 0    squared_error              20                      1
# 1    squared_error              40                      1
# 2    squared_error            None                      1
# 3     friedman_mse              20                      1
# 4     friedman_mse              40                      1
# 5     friedman_mse            None                      1
# 6          poisson              20                      1
# 7          poisson              40                      1
# 8          poisson            None                      1
# 9    squared_error              20                      7
# 10   squared_error              40                      7
# 11   squared_error            None                      7
# 12    friedman_mse              20                      7
# 13    friedman_mse              40                      7
# 14    friedman_mse            None                      7
# 15         poisson              20                      7
# 16         poisson              40                      7
# 17         poisson            None                      7
#
#    param_min_samples_split                                             params  \
# 0                        2  {'criterion': 'squared_error', 'max_depth': 20...
# 1                        2  {'criterion': 'squared_error', 'max_depth': 40...
# 2                        2  {'criterion': 'squared_error', 'max_depth': No...
# 3                        2  {'criterion': 'friedman_mse', 'max_depth': 20,...
# 4                        2  {'criterion': 'friedman_mse', 'max_depth': 40,...
# 5                        2  {'criterion': 'friedman_mse', 'max_depth': Non...
# 6                        2  {'criterion': 'poisson', 'max_depth': 20, 'min...
# 7                        2  {'criterion': 'poisson', 'max_depth': 40, 'min...
# 8                        2  {'criterion': 'poisson', 'max_depth': None, 'm...
# 9                       14  {'criterion': 'squared_error', 'max_depth': 20...
# 10                      14  {'criterion': 'squared_error', 'max_depth': 40...
# 11                      14  {'criterion': 'squared_error', 'max_depth': No...
# 12                      14  {'criterion': 'friedman_mse', 'max_depth': 20,...
# 13                      14  {'criterion': 'friedman_mse', 'max_depth': 40,...
# 14                      14  {'criterion': 'friedman_mse', 'max_depth': Non...
# 15                      14  {'criterion': 'poisson', 'max_depth': 20, 'min...
# 16                      14  {'criterion': 'poisson', 'max_depth': 40, 'min...
# 17                      14  {'criterion': 'poisson', 'max_depth': None, 'm...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0         -936.242599        -955.959652        -951.361906
# 1        -1179.887433       -1173.415986       -1204.132855
# 2        -1185.748948       -1178.086895       -1210.202582
# 3         -936.198091        -954.598429        -951.362415
# 4        -1182.237252       -1171.736849       -1203.781881
# 5        -1185.354476       -1175.642575       -1208.696665
# 6         -914.718278        -926.228416        -908.688007
# 7        -1146.612102       -1145.642068       -1174.519421
# 8        -1152.233927       -1148.887224       -1176.998168
# 9         -727.207964        -737.529423        -742.555385
# 10        -739.969201        -747.703427        -757.009797
# 11        -739.982559        -747.664558        -756.953372
# 12        -727.207747        -737.529423        -742.555385
# 13        -739.967342        -747.703524        -757.009755
# 14        -739.982074        -747.664358        -756.953340
# 15        -733.145886        -744.219211        -745.044501
# 16        -740.590135        -747.966427        -756.568109
# 17        -740.628384        -748.047743        -756.586314
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0         -956.829397        -855.919627      -931.262636       38.389977
# 1        -1182.710038       -1107.566264     -1169.542515       32.658696
# 2        -1185.028313       -1108.295386     -1173.472425       34.358975
# 3         -956.328011        -855.871748      -930.871738       38.168610
# 4        -1181.855537       -1107.329213     -1169.388146       32.742303
# 5        -1185.331482       -1111.184757     -1173.241991       32.883932
# 6         -924.802808        -825.270401      -899.941582       37.893836
# 7        -1152.998754       -1086.876735     -1141.329816       29.152530
# 8        -1157.294460       -1086.958586     -1144.474473       30.364129
# 9         -722.182115        -696.417485      -725.178474       16.092200
# 10        -738.057359        -712.739565      -739.095870       14.774944
# 11        -737.976778        -712.789620      -739.073377       14.740201
# 12        -722.182117        -696.417485      -725.178431       16.092194
# 13        -737.930167        -712.739546      -739.070067       14.776805
# 14        -738.088090        -712.786894      -739.094951       14.739548
# 15        -732.655348        -702.280146      -731.469018       15.511742
# 16        -738.258184        -712.661281      -739.208827       14.735156
# 17        -738.259335        -712.682165      -739.240788       14.742312
#
#     rank_test_score
# 0                12
# 1                16
# 2                18
# 3                11
# 4                15
# 5                17
# 6                10
# 7                13
# 8                14
# 9                 2
# 10                7
# 11                5
# 12                1
# 13                4
# 14                6
# 15                3
# 16                8
# 17                9

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_leaf': 7, 'min_samples_split': 14}

# %% [markdown]
# ### Extract the best model

# %%
best_dt = grid_search.best_estimator_

# %%
train_y_pred = np.floor(best_dt.predict(train_X)).astype(int)
test_y_pred = np.floor(best_dt.predict(test_X)).astype(int)

# %% [markdown]
# ### Plot the Tree

# %%
# _, ax = plt.subplots(1, 1, figsize=(32, 14))
# _ = plot_tree(
#     best_dt,
#     max_depth=4,
#     feature_names=train_X.columns,
#     filled=True,
#     proportion=True,
#     rounded=True,
#     precision=2,
#     fontsize=9,
#     ax=ax,
# )

# %% [markdown]
# ### Feature Importance

# %%
# feat_imp = pd.DataFrame(
#     {
#         "Feature": [x for x in best_dt.feature_names_in_],
#         "Importance": [x for x in best_dt.feature_importances_],
#     }
# )
# _, ax = plt.subplots(1, 1, figsize=(16, 9))
# _ = sns.barplot(feat_imp, x="Feature", y="Importance")
# _ = plt.title("Feature Importance for Best Decision Tree Regressor")

# %% [markdown]
# ### Visualize the Predictions

# %%
# line_fit = pd.DataFrame({"True": test_y, "Predicted": test_y_pred}, index=test_df["Day"])
# _, ax = plt.subplots(1, 1, figsize=(16,9))
# _ = sns.lineplot(line_fit, legend=True, ax=ax)

# %% [markdown]
# ### Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 22.986859254300235
# train mae: 6.575650933917046
# train r2 score: 0.7854913727012474

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 28.71175364843212
# test mae: 7.653364599172468
# test r2 score: 0.6466329998859526

# %% [markdown]
# ### Export Models

# %%
pickle.dump(best_dt, open(os.path.join(MODELS_FOLDER, "tuned_decision_tree_wo_weather.pkl"), "wb"))
