# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Import packages

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    root_mean_squared_error,
    mean_squared_error,
    mean_absolute_error,
    r2_score,
    make_scorer,
)
import pandas as pd
import numpy as np
import pickle
import os

# %%
CLEAN_DATA_FOLDER = "clean_data"
MODELS_FOLDER = "models"

# %% [markdown]
# ## Load the dataframe

# %%
train_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "train.csv"))
test_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "test.csv")).sort_values(
    ["Day", "Line", "Service", "Direction Number", "Sequence"]
)

# %% [markdown]
# ## Split into X and y

# %%
train_X = train_df[[x for x in train_df.columns if x not in ["On", "Off"]]]
train_y = train_df["On"]
test_X = test_df[[x for x in test_df.columns if x not in ["On", "Off"]]]
test_y = test_df["On"]

# %% [markdown]
# ## Train the Decision Tree Regressor Model

# %%
dt = DecisionTreeRegressor(random_state=42, criterion="poisson")
dt = dt.fit(X=train_X, y=train_y)

# %%
train_y_pred = np.floor(dt.predict(train_X)).astype(int)
test_y_pred = np.floor(dt.predict(test_X)).astype(int)

# %% [markdown]
# ## Plot the Tree

# %%
# _, ax = plt.subplots(1, 1, figsize=(32, 14))
# _ = plot_tree(
#     dt,
#     max_depth=4,
#     feature_names=train_X.columns,
#     filled=True,
#     proportion=True,
#     rounded=True,
#     precision=2,
#     fontsize=9,
#     ax=ax,
# )

# %% [markdown]
# ## Feature Importance

# %%
# feat_imp = pd.DataFrame(
#     {
#         "Feature": [x for x in dt.feature_names_in_],
#         "Importance": [x for x in dt.feature_importances_],
#     }
# )
# _, ax = plt.subplots(1, 1, figsize=(16, 9))
# _ = sns.barplot(feat_imp, x="Feature", y="Importance")
# _ = plt.title("Feature Importance for Decision Tree Regressor")

# %% [markdown]
# ## Visualize the Predictions

# %%
# line_fit = pd.DataFrame({"True": test_y, "Predicted": test_y_pred}, index=test_df["Day"])
# _, ax = plt.subplots(1, 1, figsize=(16,9))
# _ = sns.lineplot(line_fit, legend=True, ax=ax)

# %% [markdown]
# ## Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 4.00479883337299
# train mae: 0.26889678665473526
# train r2 score: 0.9934890118967664

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 38.07236030675256
# test mae: 10.010802185075336
# test r2 score: 0.3786645178275053

# %% [markdown]
# ## Export Model

# %%
pickle.dump(dt, open(os.path.join(MODELS_FOLDER, "base_decision_tree.pkl"), "wb"))

# %% [markdown]
# ## Hyperparameter Tuning with GridSearchCV

# %% [markdown]
# ### Declare base model and parameters

# %%
base_dt = DecisionTreeRegressor(random_state=42)
param_grid = [
    {
        "criterion": ["squared_error", "friedman_mse", "poisson"],
        "max_depth": [20, 40, None],
        "min_samples_split": [2],
        "min_samples_leaf": [1],
    },
    {
        "criterion": ["squared_error", "friedman_mse", "poisson"],
        "max_depth": [20, 40, None],
        "min_samples_split": [14],
        "min_samples_leaf": [7],
    },
]

# %% [markdown]
# ### Declare the scorer and grid search

# %%
scorer = make_scorer(mean_squared_error, greater_is_better=False)
grid_search = GridSearchCV(base_dt, param_grid, scoring=scorer, n_jobs=-1, verbose=2, cv=5)

# %% [markdown]
# ### Train the models

# %%
grid_search.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  31.6s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  32.0s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  32.7s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  33.2s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  33.0s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.1s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.4s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.4s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.6s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.4s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  30.7s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  42.5s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  31.1s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  43.0s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  31.4s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  42.7s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  31.7s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  32.1s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  42.8s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  44.1s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  41.4s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  41.6s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  41.4s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  41.7s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  41.3s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  41.5s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  41.1s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  41.5s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  42.3s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  43.0s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  32.1s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  32.1s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  32.3s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  33.1s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=1, min_samples_split=2; total time=  33.6s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.1s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.1s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  43.2s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  44.5s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=1, min_samples_split=2; total time=  44.3s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  27.6s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  27.5s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  27.8s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.1s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  42.3s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  41.5s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  41.9s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  42.5s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=1, min_samples_split=2; total time=  43.4s
# [CV] END criterion=squared_error, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.5s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  36.6s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  36.5s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  36.6s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  35.2s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  35.7s
# [CV] END criterion=squared_error, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  37.1s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  35.6s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  35.7s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  36.1s
# [CV] END criterion=squared_error, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  36.6s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.0s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  27.9s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  27.7s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.2s
# [CV] END criterion=friedman_mse, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.4s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  33.5s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  34.0s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  33.7s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  34.2s
# [CV] END criterion=friedman_mse, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  33.8s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  32.1s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  32.2s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  33.0s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  32.7s
# [CV] END criterion=friedman_mse, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  33.0s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.9s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  29.0s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  28.7s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  29.1s
# [CV] END criterion=poisson, max_depth=20, min_samples_leaf=7, min_samples_split=14; total time=  29.1s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  37.2s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  38.5s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  37.7s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  37.5s
# [CV] END criterion=poisson, max_depth=40, min_samples_leaf=7, min_samples_split=14; total time=  36.8s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  36.4s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  36.7s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  35.8s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  35.0s
# [CV] END criterion=poisson, max_depth=None, min_samples_leaf=7, min_samples_split=14; total time=  35.6s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid=[{'criterion': ['squared_error', 'friedman_mse',
#                                         'poisson'],
#                           'max_depth': [20, 40, None], 'min_samples_leaf': [1],
#                           'min_samples_split': [2]},
#                          {'criterion': ['squared_error', 'friedman_mse',
#                                         'poisson'],
#                           'max_depth': [20, 40, None], 'min_samples_leaf': [7],
#                           'min_samples_split': [14]}],
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       32.018134      0.536445         0.483637        0.086580
# 1       41.516360      0.168588         1.853322        0.021912
# 2       40.764480      0.538411         2.256078        0.087899
# 3       30.843978      0.397200         0.536588        0.079155
# 4       39.615143      0.218012         2.097597        0.149558
# 5       39.298535      0.652641         2.387165        0.055826
# 6       32.240023      0.535084         0.436688        0.086919
# 7       41.595801      0.540971         2.027079        0.103082
# 8       40.216851      0.637977         2.113874        0.113727
# 9       27.588221      0.359044         0.310576        0.024659
# 10      35.206098      0.622092         1.198171        0.027321
# 11      34.618646      0.281447         1.321186        0.114847
# 12      27.715600      0.205137         0.343146        0.048245
# 13      32.779077      0.197859         1.039021        0.091904
# 14      31.391003      0.348279         1.208413        0.063747
# 15      28.597695      0.142204         0.378421        0.016542
# 16      36.623861      0.543274         0.908007        0.145422
# 17      35.212394      0.506188         0.695967        0.132965
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 0    squared_error              20                      1
# 1    squared_error              40                      1
# 2    squared_error            None                      1
# 3     friedman_mse              20                      1
# 4     friedman_mse              40                      1
# 5     friedman_mse            None                      1
# 6          poisson              20                      1
# 7          poisson              40                      1
# 8          poisson            None                      1
# 9    squared_error              20                      7
# 10   squared_error              40                      7
# 11   squared_error            None                      7
# 12    friedman_mse              20                      7
# 13    friedman_mse              40                      7
# 14    friedman_mse            None                      7
# 15         poisson              20                      7
# 16         poisson              40                      7
# 17         poisson            None                      7
#
#    param_min_samples_split                                             params  \
# 0                        2  {'criterion': 'squared_error', 'max_depth': 20...
# 1                        2  {'criterion': 'squared_error', 'max_depth': 40...
# 2                        2  {'criterion': 'squared_error', 'max_depth': No...
# 3                        2  {'criterion': 'friedman_mse', 'max_depth': 20,...
# 4                        2  {'criterion': 'friedman_mse', 'max_depth': 40,...
# 5                        2  {'criterion': 'friedman_mse', 'max_depth': Non...
# 6                        2  {'criterion': 'poisson', 'max_depth': 20, 'min...
# 7                        2  {'criterion': 'poisson', 'max_depth': 40, 'min...
# 8                        2  {'criterion': 'poisson', 'max_depth': None, 'm...
# 9                       14  {'criterion': 'squared_error', 'max_depth': 20...
# 10                      14  {'criterion': 'squared_error', 'max_depth': 40...
# 11                      14  {'criterion': 'squared_error', 'max_depth': No...
# 12                      14  {'criterion': 'friedman_mse', 'max_depth': 20,...
# 13                      14  {'criterion': 'friedman_mse', 'max_depth': 40,...
# 14                      14  {'criterion': 'friedman_mse', 'max_depth': Non...
# 15                      14  {'criterion': 'poisson', 'max_depth': 20, 'min...
# 16                      14  {'criterion': 'poisson', 'max_depth': 40, 'min...
# 17                      14  {'criterion': 'poisson', 'max_depth': None, 'm...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0         -849.746842        -897.279619        -922.608781
# 1        -1076.826382       -1108.697054       -1149.469039
# 2        -1082.055098       -1115.886084       -1160.678629
# 3         -856.303037        -891.641692        -919.099496
# 4        -1068.919467       -1116.436217       -1152.580107
# 5        -1069.740935       -1116.462462       -1145.909478
# 6         -865.902555        -873.779590        -884.301041
# 7        -1086.299834       -1116.589406       -1153.562669
# 8        -1082.952380       -1115.270305       -1142.736793
# 9         -717.600006        -728.163741        -735.434050
# 10        -731.775219        -747.072639        -755.526221
# 11        -733.668342        -747.145184        -755.169762
# 12        -717.600007        -728.167585        -735.434044
# 13        -731.755362        -747.174230        -755.420723
# 14        -733.734280        -747.058675        -755.251604
# 15        -711.615475        -752.670234        -735.634247
# 16        -723.312819        -770.443620        -754.628716
# 17        -723.383531        -770.719790        -754.528441
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0         -900.474190        -910.906547      -896.203196       24.863774
# 1        -1124.072361       -1130.517218     -1117.916411       24.354184
# 2        -1118.041001       -1118.343889     -1119.000940       24.952277
# 3         -899.299062        -911.612559      -895.591169       21.827645
# 4        -1120.965490       -1112.909827     -1114.362222       26.741970
# 5        -1138.946340       -1121.366826     -1118.485208       26.680135
# 6         -915.546982        -823.533831      -872.612800       29.782857
# 7        -1156.578661       -1073.230896     -1117.252293       33.945203
# 8        -1159.054469       -1089.392089     -1117.881207       29.500872
# 9         -715.626500        -712.030222      -721.770904        8.690004
# 10        -736.543161        -733.056786      -740.794805        9.118467
# 11        -736.637069        -733.123661      -741.148804        8.640137
# 12        -715.626501        -712.030349      -721.771697        8.690540
# 13        -736.456645        -733.078037      -740.776999        9.107059
# 14        -736.639213        -733.122808      -741.161316        8.643413
# 15        -735.500006        -697.544895      -726.592972       19.540828
# 16        -749.384781        -716.527123      -742.859412       20.087032
# 17        -749.672468        -716.723914      -743.005629       20.104984
#
#     rank_test_score
# 0                12
# 1                16
# 2                18
# 3                11
# 4                13
# 5                17
# 6                10
# 7                14
# 8                15
# 9                 1
# 10                5
# 11                6
# 12                2
# 13                4
# 14                7
# 15                3
# 16                8
# 17                9

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'squared_error', 'max_depth': 20, 'min_samples_leaf': 7, 'min_samples_split': 14}

# %% [markdown]
# ### Extract the best model

# %%
best_dt = grid_search.best_estimator_

# %%
train_y_pred = np.floor(best_dt.predict(train_X)).astype(int)
test_y_pred = np.floor(best_dt.predict(test_X)).astype(int)

# %% [markdown]
# ### Plot the Tree

# %%
# _, ax = plt.subplots(1, 1, figsize=(32, 14))
# _ = plot_tree(
#     best_dt,
#     max_depth=4,
#     feature_names=train_X.columns,
#     filled=True,
#     proportion=True,
#     rounded=True,
#     precision=2,
#     fontsize=9,
#     ax=ax,
# )

# %% [markdown]
# ### Feature Importance

# %%
# feat_imp = pd.DataFrame(
#     {
#         "Feature": [x for x in best_dt.feature_names_in_],
#         "Importance": [x for x in best_dt.feature_importances_],
#     }
# )
# _, ax = plt.subplots(1, 1, figsize=(16, 9))
# _ = sns.barplot(feat_imp, x="Feature", y="Importance")
# _ = plt.title("Feature Importance for Best Decision Tree Regressor")

# %% [markdown]
# ### Visualize the Predictions

# %%
# line_fit = pd.DataFrame({"True": test_y, "Predicted": test_y_pred}, index=test_df["Day"])
# _, ax = plt.subplots(1, 1, figsize=(16,9))
# _ = sns.lineplot(line_fit, legend=True, ax=ax)

# %% [markdown]
# ### Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 21.51692017420295
# train mae: 6.321249553088095
# train r2 score: 0.812048538264482

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 28.99371217484579
# test mae: 7.75416613247825
# test r2 score: 0.6396585696426409

# %% [markdown]
# ### Export Models

# %%
pickle.dump(best_dt, open(os.path.join(MODELS_FOLDER, "tuned_decision_tree.pkl"), "wb"))
